# %%
print('hello world')
# Out:
# hello world

# %%
customer_id = 101
customer_name = "Bumi Santarin"
customer_gender = "Male"
customer_date_of_birth = "2023-05-01"
drivers_license_number = "B1234567"
auto_policy_number = "APN-123456"

# %%
print(customer_name)
# Out:
# Bumi Santarin
