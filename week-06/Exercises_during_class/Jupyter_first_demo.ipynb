# %% [markdown]
# # Data Analysis Notes

# %% [markdown]
# ## Goals

# %% [markdown]
# - Clean Data
# - Analyze trends
# - Build model

# %% [markdown]
# ### Sample Code

# %%
'''Python'''
x = 10
y = 20
print (x + y)
# Out:
# 30
